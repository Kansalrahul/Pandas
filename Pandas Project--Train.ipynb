# %%
import pandas as pd

# %%
df=pd.read_csv("train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 1. Display Top 5 Rows of The Dataset.

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#2. Check the Last 3 Rows of The Dataset
df.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# 3. Find Shape of Our Dataset (Number of Rows & Number of Columns)

print('The numbers of rows are ',df.shape[0])
print('The numbers of columns are ',df.shape[1])
# Out:
# The numbers of rows are  891
# The numbers of columns are  12

# %%
# 4. Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, 
#    Datatypes of Each Column And Memory Requirement
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# 5. Get Overall Statistics About The Dataframe

df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
# 6. Data Filtering

df[df['Sex']=='female'].head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
#7.Check Null Values In The Dataset

df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
import matplotlib as plt
import seaborn as sns

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
# 8. Drop the Column
df.drop('Cabin',axis=1,inplace=True)

# %%
# 9 Handle Missing Values

df['Embarked'].mode()
# Out:
# 0    S
# dtype: object

# %%
df['Embarked'].fillna('S',inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# dtype: int64

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df.isnull().sum()
#Now there is no null values
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
#10. Categorical Data Encoding

df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['Gender']=df['Sex'].map({'male':1,'female':0})

#in this we change the string or some categorical values into intergers or numeric value that wew can access easily for analysis

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  Gender
# 0      0         A/5 21171   7.2500        S       1
# 1      0          PC 17599  71.2833        C       0
# 2      0  STON/O2. 3101282   7.9250        S       0
# 3      0            113803  53.1000        S       0
# ...

# %%
r=df['Sex'].map({'male':1,'female':0})

# %%
df.insert(5,'Gender M/F',r)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Gender M/F  \
# 0                            Braund, Mr. Owen Harris    male           1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female           0
# 2                             Heikkinen, Miss. Laina  female           0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female           0
# 4                           Allen, Mr. William Henry    male           1
#
#     Age  SibSp  Parch            Ticket     Fare Embarked  Gender
# 0  22.0      1      0         A/5 21171   7.2500        S       1
# 1  38.0      1      0          PC 17599  71.2833        C       0
# 2  26.0      0      0  STON/O2. 3101282   7.9250        S       0
# ...

# %%
# if we have many number of category

df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
pd.get_dummies(df,columns=['Embarked'])

# by this we have categorize all the categries of embarked
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Gender M/F  \
# 0                              Braund, Mr. Owen Harris    male           1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female           0
# 2                               Heikkinen, Miss. Laina  female           0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female           0
# 4                             Allen, Mr. William Henry    male           1
# ..                                                 ...     ...         ...
# ...

# %%
pd.get_dummies(df,columns=['Embarked'],drop_first=True)

# if we want to drop category of column
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Gender M/F  \
# 0                              Braund, Mr. Owen Harris    male           1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female           0
# 2                               Heikkinen, Miss. Laina  female           0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female           0
# 4                             Allen, Mr. William Henry    male           1
# ..                                                 ...     ...         ...
# ...

# %%
#11. What is Univariate Analysis?
# a.How Many People Survived And How Many Died?

df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
sns.countplot(df['Survived'])
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
# b.How Many Passengers Were In First Class, Second Class, and Third Class?
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
sns.countplot(df['Pclass'])
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
# c.Number of Male And Female Passengers

df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
sns.countplot(df['Sex'])
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.boxplot(df['Age'],orient='v')
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# <AxesSubplot:xlabel='Age'>

# %%
# 12. Bivariate Analysis

# %%
# a.Who Has Better Chance of Survival Male or Female ?
sns.barplot(x='Sex',y='Survived',data=df)

# in this we can say that Female has more chances to Survive
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Survived'>

# %%
# b.  Which Passenger Class Has Better Chance of Survival (First, Second, Or Third Class)?

sns.barplot(x='Pclass',y='Survived',data=df)

# as we can say that class 1 as better chances of survival
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %%
# 13. Feature Engineering
# it means we modify data as per our according

df['Family_size']=df['SibSp']+df['Parch']

# here we have add both column to know that how many members is family

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Gender M/F  \
# 0                              Braund, Mr. Owen Harris    male           1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female           0
# 2                               Heikkinen, Miss. Laina  female           0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female           0
# 4                             Allen, Mr. William Henry    male           1
# ..                                                 ...     ...         ...
# ...

# %%
df['fare_per_person']=(df['Fare']/df['Family_size'])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Gender M/F  \
# 0                              Braund, Mr. Owen Harris    male           1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female           0
# 2                               Heikkinen, Miss. Laina  female           0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female           0
# 4                             Allen, Mr. William Henry    male           1
# ..                                                 ...     ...         ...
# ...
