# %%
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 1. How many male and female are there?

df['Sex'].value_counts()

# through value_counts() method we have to count the column data
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
len(df[df['Sex']=='male'])
# Out:
# 577

# %%
len(df[df['Sex']=='female'])
# Out:
# 314

# %%
df.groupby('Sex')['Sex'].count()
# Out:
# Sex
# female    314
# male      577
# Name: Sex, dtype: int64

# %%
#2. How many suvived ?

df['Survived'].value_counts()[1]

# through value_counts() method we have to count the column data and then we have to give value of which count we need
# Out:
# 342

# %%
# 3. How many casuality ?

df['Survived'].value_counts()[0]
# Out:
# 549

# %%
# " 4. What is the name of a person who is the eldest one?

df[df['Age']==max(df['Age'])]['Name']
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
# 5. How many passenger are there in the first, second and third class?

df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df['Pclass'].value_counts()[2]
# Out:
# 184

# %%
df['Pclass'].value_counts()[3]
# Out:
# 491

# %%
# " 6. How many people whose name start with S
df[df['Name'].str.startswith('S')==True]
# Out:
#      PassengerId  Survived  Pclass  \
# 10            11         1       3
# 12            13         0       3
# 23            24         1       1
# 31            32         1       1
# 48            49         0       3
# ..           ...       ...     ...
# 851          852         0       3
# 862          863         1       1
# 863          864         0       3
# 880          881         1       2
# 884          885         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 12                      Saundercock, Mr. William Henry    male  20.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 48                                 Samaan, Mr. Youssef    male   NaN      2
# ..                                                 ...     ...   ...    ...
# ...

# %%
# " 7. Try to create a new column which is a summation of SibSp and parch

df['SibSp_Parch']=df['SibSp']+df['Parch']

# %%
# " 8. How many people have the age below 25?

Ag=df['Age']<25

# %%
len(df[df['Age']<25])
# Out:
# 278

# %%
Ag.value_counts()[True]
# Out:
# 278

# %%
df[Ag]
# Out:
#      PassengerId  Survived  Pclass                                 Name  \
# 0              1         0       3              Braund, Mr. Owen Harris
# 7              8         0       3       Palsson, Master. Gosta Leonard
# 9             10         1       2  Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3      Sandstrom, Miss. Marguerite Rut
# 12            13         0       3       Saundercock, Mr. William Henry
# ..           ...       ...     ...                                  ...
# 875          876         1       3     Najib, Miss. Adele Kiamie "Jane"
# 876          877         0       3        Gustafsson, Mr. Alfred Ossian
# 877          878         0       3                 Petroff, Mr. Nedelio
# 882          883         0       3         Dahlberg, Miss. Gerda Ulrika
# 887          888         1       1         Graham, Miss. Margaret Edith
#
#         Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked  \
# ...

# %%
# " 9. How many people died whose age less than 40?

len(df[(df['Survived'] == 0) & (df['Age']<40)])
# Out:
# 322

# %%
# " 10. From a Cabine column, seperate text and numeric value"

df['Cabin2']=df['Cabin'].str.extract('(\d+)')

# %%
df['Cabin3']=df['Cabin'].str.extract('(\D+)')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import re
# we have to import regex package to do regular expressions operations
replace=re.compile('([a-zA-z]+)')

df['String_cabin']=df['Cabin'].str.extract(replace)
df['Num_cabin']=df['Cabin'].str.replace(replace,"")


# here in this we have to extract first where alphabets occurs in cabin
# after that in num cabin we have to replace alphabets with blank to separate the numbers

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2=pd.DataFrame(df.Cabin.str.split('([a-zA-Z]+)([^a-zA-Z]+)'))
df2

#  it means([^a-zA-Z]+)')) not equals to this value we have to split .
# Out:
#             Cabin
# 0             NaN
# 1     [, C, 85, ]
# 2             NaN
# 3    [, C, 123, ]
# 4             NaN
# ..            ...
# 886           NaN
# 887   [, B, 42, ]
# 888           NaN
# 889  [, C, 148, ]
# 890           NaN
#
# [891 rows x 1 columns]
